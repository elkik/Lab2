# %%
chemin = "C:/Users/pc/Documents/université/session 5/A21/Lab 2/Données python/régression/F_ATV.xlsx"

# %%
chemin
# Out:
# 'C:/Users/pc/Documents/université/session 5/A21/Lab 2/Données python/régression/F_ATV.xlsx'

# %%
import pandas

# %%
df =pandas.read_excel(chemin)

# %%
df
# Out:
#     group_tab ML_FoldInd      ML_Area       ML_Vol  ML_Thick  Unnamed: 5  \
# 0      group1  40.029412  2507.147059  6642.911765  2.423941         NaN
# 1      group1  37.529412  2208.470588  5691.411765  2.391294         NaN
# 2      group1  36.911765       2076.5  5656.823529  2.492971         NaN
# 3      group1  35.735294  2238.588235  5748.088235  2.437412         NaN
# 4      group1  36.264706  2421.264706  7071.794118  2.635265         NaN
# ..        ...        ...          ...          ...       ...         ...
# 176    group2  35.117647  2099.441176         5627  2.448235         NaN
# 177    group2  35.117647  2293.705882  6297.235294  2.476471         NaN
# 178    group2  38.588235  2509.029412  6182.764706  2.294971         NaN
# 179    group2  35.382353  2299.941176  6033.911765  2.432824         NaN
# 180    group2  33.235294  2158.352941  5632.382353  2.423471         NaN
#
#      Unnamed: 6  Unnamed: 7
# 0           NaN         NaN
# 1           NaN         NaN
# ...

# %%
df_group1 = df[df['group_tab'] == 'group1']
df_group2 = df[df['group_tab'] == 'group2']

# %%
import matplotlib.pyplot as plt
ax1 = df[df['group_tab'] == 'group1'].plot(kind='scatter', x='ML_FoldInd', y='ML_Area', color='blue', alpha=0.5, figsize=(10,7))
df[df['group_tab'] == 'group2'].plot(kind='scatter', x='ML_FoldInd', y='ML_Area', color='Magenta', alpha=0.5, figsize=(10,7), ax=ax1)
plt.legend(labels=['group1', 'group2'])
plt.title('Relationship between ML_FoldInd and ML_Area', size=24)
# Out:
# Text(0.5, 1.0, 'Relationship between ML_FoldInd and ML_Area')

# %%
df_group1 = df[df['group_tab'] == 'group1']
df_group2 = df[df['group_tab'] == 'group2']

# %%
import matplotlib.pyplot as plt
ax1 = df[df['group_tab'] == 'group1'].plot(kind='scatter', x='ML_FoldInd', y='ML_Vol', color='blue', alpha=0.5, figsize=(10,7))
df[df['group_tab'] == 'group2'].plot(kind='scatter', x='ML_FoldInd', y='ML_Vol', color='Magenta', alpha=0.5, figsize=(10,7), ax=ax1)
plt.legend(labels=['group1', 'group2'])
plt.title('Relationship between ML_FoldInd and ML_Vol', size=24)
# Out:
# Text(0.5, 1.0, 'Relationship between ML_FoldInd and ML_Vol')

# %%
df_group1 = df[df['group_tab'] == 'group1']
df_group2 = df[df['group_tab'] == 'group2']

# %%
import matplotlib.pyplot as plt
ax1 = df[df['group_tab'] == 'group1'].plot(kind='scatter', x='ML_FoldInd', y='ML_Thick', color='blue', alpha=0.5, figsize=(10,7))
df[df['group_tab'] == 'group2'].plot(kind='scatter', x='ML_FoldInd', y='ML_Thick', color='Magenta', alpha=0.5, figsize=(10,7), ax=ax1)
plt.legend(labels=['group1', 'group2'])
plt.title('Relationship between ML_FoldInd and ML_Thick', size=24)
# Out:
# Text(0.5, 1.0, 'Relationship between ML_FoldInd and ML_Thick')
