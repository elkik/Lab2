# %%
chemin = 'C:/Users/pc/Documents/université/session 5/A21/Lab 2/Données python/régression/FR_ATV.xlsx'

# %%
chemin
# Out:
# 'C:/Users/pc/Documents/université/session 5/A21/Lab 2/Données python/régression/FR_ATV.xlsx'

# %%
import pandas

# %%
df = pandas.read_excel(chemin)

# %%
df
# Out:
#     goup_tab MR_FoldInd       MR_Vol      MR_Area  MR_Thick
# 0     group1  39.794118  6583.529412  2475.205882  2.421294
# 1     group1       37.5  5774.676471  2239.823529     2.374
# 2     group1  35.911765  5777.441176  2072.352941  2.577618
# 3     group1  35.735294         5802  2228.676471  2.436765
# 4     group1  37.117647  7040.058824  2400.823529  2.618735
# ..       ...        ...          ...          ...       ...
# 176  group2   35.911765  5739.176471         2147  2.457882
# 177  group2   34.970588  6348.176471  2276.294118  2.511941
# 178  group2        38.5  6204.176471  2564.852941  2.261735
# 179  group2   34.970588  6044.911765  2297.294118  2.450676
# 180  group2   33.676471  5693.205882  2189.323529    2.4045
#
# [181 rows x 5 columns]

# %%
df_group1 = df[df['goup_tab'] == 'group1']
df_group2 = df[df['goup_tab'] == 'group2']

# %%
import matplotlib.pyplot as plt
ax1 = df[df['goup_tab'] == 'group1'].plot(kind='scatter', x='MR_FoldInd', y='MR_Area', color='blue', alpha=0.5, figsize=(10,7))
df[df['goup_tab'] == 'group2'].plot(kind='scatter', x='MR_FoldInd', y='MR_Area', color='Magenta', alpha=0.5, figsize=(10,7), ax=ax1)
plt.legend(labels=['group1', 'group2'])
plt.title('Relationship between MR_FoldInd and MR_Area', size=24)
# Out:
# Text(0.5, 1.0, 'Relationship between MR_FoldInd and MR_Area')

# %%
df_group1 = df[df['goup_tab'] == 'group1']
df_group2 = df[df['goup_tab'] == 'group2']

# %%
import matplotlib.pyplot as plt
ax1 = df[df['goup_tab'] == 'group1'].plot(kind='scatter', x='MR_FoldInd', y='MR_Vol', color='blue', alpha=0.5, figsize=(10,7))
df[df['goup_tab'] == 'group2'].plot(kind='scatter', x='MR_FoldInd', y='MR_Vol', color='Magenta', alpha=0.5, figsize=(10,7), ax=ax1)
plt.legend(labels=['group1', 'group2'])
plt.title('Relationship between MR_FoldInd and MR_Vol', size=24)
# Out:
# Text(0.5, 1.0, 'Relationship between MR_FoldInd and MR_Vol')

# %%
df_group1 = df[df['goup_tab'] == 'group1']
df_group2 = df[df['goup_tab'] == 'group2']

# %%
import matplotlib.pyplot as plt
ax1 = df[df['goup_tab'] == 'group1'].plot(kind='scatter', x='MR_FoldInd', y='MR_Thick', color='blue', alpha=0.5, figsize=(10,7))
df[df['goup_tab'] == 'group2'].plot(kind='scatter', x='MR_FoldInd', y='MR_Thick', color='Magenta', alpha=0.5, figsize=(10,7), ax=ax1)
plt.legend(labels=['group1', 'group2'])
plt.title('Relationship between MR_FoldInd and MR_Thick', size=24)
# Out:
# Text(0.5, 1.0, 'Relationship between MR_FoldInd and MR_Thick')
